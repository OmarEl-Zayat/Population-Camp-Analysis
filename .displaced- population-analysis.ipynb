# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarEl-Zayat/displaced-population-analysis/blob/main/.displaced-%20population-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step1:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/4_6007878812891618215.xlsx')

# %%
df.head(10)
# Out:
#         Date Country       City         PlaceName  Houses  Members  Male  \
# 0 2017-01-29    Iraq       Afak     تجمع الفلاحين     158    14036  3722
# 1 2017-01-29    Iraq       Afak     تجمع الفلاحين      81     1537   805
# 2 2017-01-29   Lybia      Bayda  أول طلعة الأوسطى      84     2864   992
# 3 2017-01-29   Lybia       Marj            سبلبات      82     3652  1559
# 4 2017-01-29   Syria       Atma    تجمع باب الهوى     131     4505  2895
# 5 2017-01-29   Syria       Atma    تجمع باب الهوى      92     2682  1481
# 6 2017-01-29   Syria       Atma    تجمع باب الهوى     116     7710  2584
# 7 2017-01-29   Syria   Jarablus     المخيم التركي     158    10509  3422
# 8 2017-01-29   Syria   Jarablus     المخيم التركي     158    10570  4524
# 9 2017-01-29   Syria  Khantuman      مساكن العمال      93     2999  1268
#
#    Female  Room  Flat  House   Tent
# 0   10314  47.0  79.0   32.0    NaN
# 1     732  24.0  41.0   16.0    NaN
# 2    1872  25.0  42.0   17.0    NaN
# 3    2093  25.0  41.0   16.0    NaN
# 4    1610  39.0  66.0   26.0    NaN
# 5    1201  28.0  46.0   18.0    NaN
# 6    5126  35.0  58.0   23.0    NaN
# 7    7087   NaN   NaN    NaN  158.0
# 8    6046   NaN   NaN    NaN  158.0
# 9    1731  27.0  47.0   19.0    NaN

# %%
df.tail(10)
# Out:
#            Date Country         City          PlaceName  Houses  Members  \
# 9907 2018-11-14   Yemen         Aden        السليمانيات      95      889
# 9908 2018-11-14   Yemen  Al Hudaydah      مخيمات الخربة      95     9095
# 9909 2018-11-14   Yemen  Al Hudaydah      مخيمات الخربة      82     5865
# 9910 2018-11-14   Yemen          Ibb  التجمعات السكانية     116     4306
# 9911 2018-11-14   Yemen          Ibb  التجمعات السكانية     141     3794
# 9912 2018-11-14   Yemen          Ibb  التجمعات السكانية     128     9925
# 9913 2018-11-14   Yemen       Sana'a      مدارس التربية      93     2505
# 9914 2018-11-14   Yemen       Sana'a      مدارس التربية     158     2846
# 9915 2018-11-14   Yemen       Sana'a      مدارس التربية     110     5444
# 9916 2018-11-14   Yemen       Sana'a      مدارس التربية     119     4870
#
#       Male  Female  Room  Flat  House  Tent
# 9907   252     637  28.0  48.0   19.0   NaN
# 9908  3086    6009   NaN   NaN    NaN  95.0
# 9909  3323    2542   NaN   NaN    NaN  82.0
# 9910  1247    3059  35.0  58.0   23.0   NaN
# 9911  2266    1528  42.0  71.0   28.0   NaN
# 9912  4962    4963  38.0  64.0   26.0   NaN
# 9913   878    1627  27.0  47.0   19.0   NaN
# 9914   870    1976  47.0  79.0   32.0   NaN
# 9915  2130    3314  33.0  55.0   22.0   NaN
# 9916  3241    1629  35.0  60.0   24.0   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9917 entries, 0 to 9916
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9917 non-null   datetime64[ns]
#  1   Country    9917 non-null   object
#  2   City       9917 non-null   object
#  3   PlaceName  9917 non-null   object
#  4   Houses     9917 non-null   int64
#  5   Members    9917 non-null   int64
#  6   Male       9917 non-null   int64
#  7   Female     9917 non-null   int64
#  8   Room       7588 non-null   float64
#  9   Flat       7588 non-null   float64
#  10  House      7588 non-null   float64
#  11  Tent       2329 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(3)
# memory usage: 929.8+ KB

# %%
df.isnull().sum()
# Out:
# Date            0
# Country         0
# City            0
# PlaceName       0
# Houses          0
# Members         0
# Male            0
# Female          0
# Room         2329
# Flat         2329
# House        2329
# Tent         7588
# dtype: int64

# %%
df.describe()
# Out:
#                                 Date       Houses       Members          Male  \
# count                           9917  9917.000000   9917.000000   9917.000000
# mean   2017-12-22 18:45:46.556418304   119.756075   5950.039125   2576.633861
# min              2017-01-29 00:00:00    80.000000      5.000000      2.000000
# 25%              2017-07-10 00:00:00    99.000000   2850.000000   1098.000000
# 50%              2017-12-24 00:00:00   119.000000   5666.000000   2224.000000
# 75%              2018-06-06 00:00:00   140.000000   8628.000000   3679.000000
# max              2018-11-14 00:00:00   160.000000  15933.000000  10112.000000
# std                              NaN    23.548772   3705.627027   1867.506097
#
#              Female         Room         Flat        House         Tent
# count   9917.000000  7588.000000  7588.000000  7588.000000  2329.000000
# mean    3373.405264    35.674618    60.116895    23.948998   119.806784
# min        2.000000    24.000000    40.000000    16.000000    80.000000
# 25%     1534.000000    29.000000    50.000000    20.000000    99.000000
# 50%     3062.000000    35.000000    60.000000    24.000000   120.000000
# 75%     4799.000000    42.000000    70.000000    28.000000   141.000000
# max    12265.000000    48.000000    80.000000    32.000000   160.000000
# std     2289.695298     7.019073    11.715428     4.698043    23.995893

# %%
df.describe(include='object')
# Out:
#        Country  City    PlaceName
# count     9917  9917         9917
# unique       4    19           19
# top      Yemen  Aden  السليمانيات
# freq      3989   703          703

# %% [markdown]
# Step2:

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['year']=df['Date'].dt.year
df['month']=df['Date'].dt.month
df['day']=df['Date'].dt.day

# %%
df[['Date', 'year', 'month', 'day']].head()
# Out:
#         Date  year  month  day
# 0 2017-01-29  2017      1   29
# 1 2017-01-29  2017      1   29
# 2 2017-01-29  2017      1   29
# 3 2017-01-29  2017      1   29
# 4 2017-01-29  2017      1   29

# %%
df.isnull().sum()
# Out:
# Date            0
# Country         0
# City            0
# PlaceName       0
# Houses          0
# Members         0
# Male            0
# Female          0
# Room         2329
# Flat         2329
# House        2329
# Tent         7588
# year            0
# month           0
# day             0
# dtype: int64

# %%
Total_Cells=df.shape[0]*df.shape[1]
Total_Missing=df.isnull().sum().sum()
Missing_Percentage=(Total_Missing/Total_Cells)*100
print(Missing_Percentage)
# Out:
# 9.797989983529966

# %%
Missing_Cols=['Flat','Room', 'House', 'Tent']
df[Missing_Cols]=df[Missing_Cols].fillna(0)

# %%
text_col=['Country','City']
for col in text_col:
  df[col]=df[col].astype(str).str.strip()

# %%
Total_Cells=df.shape[0]*df.shape[1]
Total_Missing_After_Handling=df.isnull().sum().sum()
Complete_Percentage=((Total_Cells - Total_Missing_After_Handling)/Total_Cells)*100
print(Complete_Percentage)
# Out:
# 100.0

# %% [markdown]
# Step3:

# %%
df['Male_Percentage']=np.where(df['Members']>0,(df['Male']/df['Members']*100), 0)
df['Female_Percentage']=np.where(df['Members']>0,(df['Female']/df['Members']*100), 0)

# %%
df['Avg_People_Per_House']=np.where(df['House']>0,(df['Members']/df['House']), 0)

# %%
housing_type= ['Flat', 'Room', 'House', 'Tent']
df['Dominant_Housing']=df[housing_type].idxmax(axis=1)

# %%
df[['Male_Percentage', 'Female_Percentage', 'Avg_People_Per_House', 'Dominant_Housing']].head()
# Out:
#    Male_Percentage  Female_Percentage  Avg_People_Per_House Dominant_Housing
# 0        26.517526          73.482474            438.625000             Flat
# 1        52.374756          47.625244             96.062500             Flat
# 2        34.636872          65.363128            168.470588             Flat
# 3        42.688938          57.311062            228.250000             Flat
# 4        64.261931          35.738069            173.269231             Flat

# %% [markdown]
# Step4:

# %%
country_summary=df.groupby('Country')[['Members', 'Male', 'Female']].sum()
country_summary
# Out:
#           Members      Male    Female
# Country
# Iraq      7869862   3432382   4437480
# Lybia     7719390   3327501   4391889
# Syria    19457159   8436522  11020637
# Yemen    23960127  10356073  13604054

# %%
country_year_summary=df.groupby(['Country', 'year'])[['Members']].sum()
country_year_summary
# Out:
#                Members
# Country year
# Iraq    2017   4006017
#         2018   3863845
# Lybia   2017   3969142
#         2018   3750248
# Syria   2017   9905466
#         2018   9551693
# Yemen   2017  12261561
#         2018  11698566

# %%
country_year_summary=df.groupby(['Country', 'year'])[['Members']].sum().unstack()
country_year_summary
# Out:
#           Members
# year         2017      2018
# Country
# Iraq      4006017   3863845
# Lybia     3969142   3750248
# Syria     9905466   9551693
# Yemen    12261561  11698566

# %%
house_pivot_table=pd.pivot_table(df, index='Country', columns='year', values='House', aggfunc='sum')
house_pivot_table
# Out:
# year        2017     2018
# Country
# Iraq     12423.0  11820.0
# Lybia    16137.0  15057.0
# Syria    23179.0  23602.0
# Yemen    40704.0  38803.0

# %% [markdown]
# Step5:

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
features=['Houses', 'Members', 'Avg_People_Per_House']
m=MinMaxScaler()
s=StandardScaler()
df[[f'{col}_scaled' for col in features]]=m.fit_transform(df[features])
df[['Houses_scaled', 'Members_scaled', 'Avg_People_Per_House_scaled']].head()
# Out:
#    Houses_scaled  Members_scaled  Avg_People_Per_House_scaled
# 0         0.9750        0.880902                     0.856585
# 1         0.0125        0.096183                     0.187599
# 2         0.0500        0.179495                     0.329004
# 3         0.0250        0.228968                     0.445746
# 4         0.6375        0.282521                     0.338375

# %%
df['Members_zscore']=s.fit_transform(df[['Members']])
df[['Members', 'Members_zscore']].head()
# Out:
#    Members  Members_zscore
# 0    14036        2.182186
# 1     1537       -1.190962
# 2     2864       -0.832840
# 3     3652       -0.620180
# 4     4505       -0.389978

# %%
outliers=df[df['Members_zscore'].abs()>3]
outliers.head()
# Out:
# Empty DataFrame
# Columns: [Date, Country, City, PlaceName, Houses, Members, Male, Female, Room, Flat, House, Tent, year, month, day, Male_Percentage, Female_Percentage, Avg_People_Per_House, Dominant_Housing, Houses_scaled, Members_scaled, Avg_People_Per_House_scaled, Members_zscore]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# Step6:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
country_members=df.groupby('Country')['Members'].sum()
plt.bar(country_members.index, country_members.values)
plt.xlabel('Country')
plt.ylabel('Total Members')
plt.title('Total Members by Country')
plt.show()

# %%
year_country=df.groupby(['year', 'Country'])['Members'].sum().reset_index()
sns.lineplot(x='year', y='Members', hue='Country', data=year_country)
plt.xlabel('Year')
plt.ylabel('Total Members')
plt.title('Total Members by Year and Country')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='Male_Percentage', label='Male Percentage', fill=True, alpha=0.6, linewidth=2)
sns.kdeplot(data=df, x='Female_Percentage', label='Female Percentage', fill=True, alpha=0.6, linewidth=2)
plt.xlabel('Percentage')
plt.ylabel('Density')
plt.title('Distribution of Male and Female Percentages')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
sns.regplot(data=df, x='Houses', y='Members')
plt.xlabel('Houses')
plt.ylabel('Members')
plt.title('Relationship Between Houses & Members Relationship')
plt.show()

# %%
correlation=df.corr(numeric_only=True)
plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
